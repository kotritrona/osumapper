# %% [markdown]
# ## osumapper #1: Map Dataset Reader
#
# Read the map list and convert maps to formats Python can use.

# %% [markdown]
# ### IMPORTANT!! First fill "maplist.txt" with paths of .osu files you want to train with !!!
#
# You can use the maplist generator by running `node gen_maplist` under this directory.
#
# **Tip:** Don't train with your every single map. Find good maps (maps you like) with relatively similar difficulty.
#
# After that, run the grid below to convert the maps.

# %%
# from act_data_prep import *

# for osu!mania use this instead of above
from mania_act_data_prep import * 

step1_load_maps();

# If any map causes bug please tell me!! https://discord.gg/npmSy7K
# Out:
# Number of filtered maps: 188
# Map data #0 saved! time = 1.5431067943572998 secs
# Map data #1 saved! time = 1.5227346420288086 secs
# Map data #2 saved! time = 0.708573579788208 secs
# Map data #3 saved! time = 0.6626183986663818 secs
# Map data #4 saved! time = 1.0846519470214844 secs
# Map data #5 saved! time = 1.1953299045562744 secs
# Map data #6 saved! time = 0.6036527156829834 secs
# Map data #7 saved! time = 2.0372610092163086 secs
# Map data #8 saved! time = 3.475999593734741 secs
# Map data #9 saved! time = 4.228566408157349 secs
# Map data #10 saved! time = 4.117631196975708 secs
# Map data #11 saved! time = 1.9594230651855469 secs
# Map data #12 saved! time = 2.5631651878356934 secs
# Map data #13 saved! time = 2.515164613723755 secs
# Map data #14 saved! time = 1.8409390449523926 secs
# Map data #15 saved! time = 1.6630444526672363 secs
# Map data #16 saved! time = 2.743812084197998 secs
# Map data #17 saved! time = 2.2354648113250732 secs
# Map data #18 saved! time = 4.041010856628418 secs
# Map data #19 saved! time = 1.3162636756896973 secs
# Map data #20 saved! time = 1.6324636936187744 secs
# Map data #21 saved! time = 2.57914400100708 secs
# Map data #22 saved! time = 1.8228259086608887 secs
# Map data #23 saved! time = 1.6501038074493408 secs
# Map data #24 saved! time = 1.3661117553710938 secs
# Map data #25 saved! time = 1.4731385707855225 secs
# Map data #26 saved! time = 2.132390022277832 secs
# Map data #27 saved! time = 1.1666467189788818 secs
# Map data #28 saved! time = 1.1573398113250732 secs
# Map data #29 saved! time = 5.479629755020142 secs
# Map data #30 saved! time = 5.610064268112183 secs
# Map data #31 saved! time = 4.846104860305786 secs
# Map data #32 saved! time = 1.3617784976959229 secs
# Map data #33 saved! time = 1.9023008346557617 secs
# Map data #34 saved! time = 1.599858283996582 secs
# Map data #35 saved! time = 1.7727465629577637 secs
# Map data #36 saved! time = 1.916785478591919 secs
# Map data #37 saved! time = 1.7695598602294922 secs
# Map data #38 saved! time = 1.308046817779541 secs
# Map data #39 saved! time = 1.435774803161621 secs
# Map data #40 saved! time = 2.414316177368164 secs
# Map data #41 saved! time = 2.087634801864624 secs
# Map data #42 saved! time = 2.6191341876983643 secs
# Map data #43 saved! time = 2.332024097442627 secs
# Map data #44 saved! time = 2.4396908283233643 secs
# Map data #45 saved! time = 1.1762564182281494 secs
# Map data #46 saved! time = 1.9446461200714111 secs
# Map data #47 saved! time = 1.6628539562225342 secs
# Map data #48 saved! time = 1.7242465019226074 secs
# Map data #49 saved! time = 0.8593487739562988 secs
# Map data #50 saved! time = 0.8332610130310059 secs
# Map data #51 saved! time = 1.2835979461669922 secs
# Map data #52 saved! time = 1.3254010677337646 secs
# Map data #53 saved! time = 0.7565653324127197 secs
# Map data #54 saved! time = 1.8442740440368652 secs
# Map data #55 saved! time = 2.280231237411499 secs
# Map data #56 saved! time = 1.03863525390625 secs
# Map data #57 saved! time = 1.548722267150879 secs
# Map data #58 saved! time = 1.9712047576904297 secs
# Map data #59 saved! time = 1.7665653228759766 secs
# Map data #60 saved! time = 2.176084041595459 secs
# Map data #61 saved! time = 2.0554494857788086 secs
# Map data #62 saved! time = 2.900663137435913 secs
# Map data #63 saved! time = 3.1069066524505615 secs
# Map data #64 saved! time = 2.8152618408203125 secs
# Map data #65 saved! time = 1.6649675369262695 secs
# Map data #66 saved! time = 1.4104266166687012 secs
# Map data #67 saved! time = 1.4497075080871582 secs
# Map data #68 saved! time = 1.5536317825317383 secs
# Map data #69 saved! time = 1.9081928730010986 secs
# Map data #70 saved! time = 1.8049631118774414 secs
# Map data #71 saved! time = 1.724334478378296 secs
# Map data #72 saved! time = 1.130345344543457 secs
# Map data #73 saved! time = 1.3135309219360352 secs
# Map data #74 saved! time = 2.1338226795196533 secs
# Map data #75 saved! time = 1.9928531646728516 secs
# Map data #76 saved! time = 1.4301767349243164 secs
# Map data #77 saved! time = 1.713019609451294 secs
# Map data #78 saved! time = 1.568099021911621 secs
# Map data #79 saved! time = 1.5163931846618652 secs
# Map data #80 saved! time = 1.610948085784912 secs
# Map data #81 saved! time = 2.7413249015808105 secs
# Map data #82 saved! time = 3.0462393760681152 secs
# Map data #83 saved! time = 2.835369825363159 secs
# Map data #84 saved! time = 3.3808417320251465 secs
# Map data #85 saved! time = 3.3070967197418213 secs
# Map data #86 saved! time = 2.461591958999634 secs
# Map data #87 saved! time = 2.2407097816467285 secs
# Map data #88 saved! time = 2.0928337574005127 secs
# Map data #89 saved! time = 3.4441308975219727 secs
# Map data #90 saved! time = 3.3764593601226807 secs
# Map data #91 saved! time = 1.4240343570709229 secs
# Map data #92 saved! time = 1.6505155563354492 secs
# Map data #93 saved! time = 1.5983493328094482 secs
# Map data #94 saved! time = 1.3442676067352295 secs
# Map data #95 saved! time = 1.8425052165985107 secs
# Map data #96 saved! time = 1.2168786525726318 secs
# Map data #97 saved! time = 1.2169883251190186 secs
# Map data #98 saved! time = 1.3901588916778564 secs
# Map data #99 saved! time = 1.2741942405700684 secs
# Map data #100 saved! time = 1.2477991580963135 secs
# Map data #101 saved! time = 1.260422706604004 secs
# Map data #102 saved! time = 1.4507777690887451 secs
# Map data #103 saved! time = 1.4267578125 secs
# Map data #104 saved! time = 1.1988897323608398 secs
# Map data #105 saved! time = 1.2321624755859375 secs
# Map data #106 saved! time = 1.286344289779663 secs
# Map data #107 saved! time = 1.3136823177337646 secs
# Map data #108 saved! time = 1.0644023418426514 secs
# Map data #109 saved! time = 1.4339687824249268 secs
# Map data #110 saved! time = 1.3956201076507568 secs
# Map data #111 saved! time = 1.5951058864593506 secs
# Map data #112 saved! time = 1.2047243118286133 secs
# Map data #113 saved! time = 1.3960325717926025 secs
# Map data #114 saved! time = 1.6894583702087402 secs
# Map data #115 saved! time = 1.0404915809631348 secs
# Map data #116 saved! time = 0.9980556964874268 secs
# Map data #117 saved! time = 1.419722080230713 secs
# Map data #118 saved! time = 1.2734172344207764 secs
# Map data #119 saved! time = 1.4362668991088867 secs
# Map data #120 saved! time = 1.3843481540679932 secs
# Map data #121 saved! time = 1.3373136520385742 secs
# Map data #122 saved! time = 1.3968331813812256 secs
# Map data #123 saved! time = 1.4601614475250244 secs
# Map data #124 saved! time = 1.8239834308624268 secs
# Map data #125 saved! time = 1.9469051361083984 secs
# Map data #126 saved! time = 2.2866835594177246 secs
# Map data #127 saved! time = 5.277988910675049 secs
# Map data #128 saved! time = 5.573791980743408 secs
# Map data #129 saved! time = 1.9666454792022705 secs
# Map data #130 saved! time = 1.9308903217315674 secs
# Map data #131 saved! time = 3.6967520713806152 secs
# Map data #132 saved! time = 2.0647575855255127 secs
# Map data #133 saved! time = 2.0984530448913574 secs
# Map data #134 saved! time = 2.1468307971954346 secs
# Map data #135 saved! time = 0.7972919940948486 secs
# Map data #136 saved! time = 0.7236018180847168 secs
# Map data #137 saved! time = 2.0318408012390137 secs
# Map data #138 saved! time = 2.2337145805358887 secs
# Map data #139 saved! time = 3.962721824645996 secs
# Map data #140 saved! time = 1.5231378078460693 secs
# Map data #141 saved! time = 1.4221601486206055 secs
# Map data #142 saved! time = 1.5591003894805908 secs
# Map data #143 saved! time = 1.7499895095825195 secs
# Map data #144 saved! time = 1.2293109893798828 secs
# Map data #145 saved! time = 1.2775771617889404 secs
# Map data #146 saved! time = 2.1263821125030518 secs
# Map data #147 saved! time = 1.663050651550293 secs
# Map data #148 saved! time = 1.954876184463501 secs
# Map data #149 saved! time = 2.131962776184082 secs
# Map data #150 saved! time = 1.438173770904541 secs
# Map data #151 saved! time = 1.535151481628418 secs
# Map data #152 saved! time = 1.9298896789550781 secs
# Map data #153 saved! time = 1.678035020828247 secs
# Map data #154 saved! time = 1.5571050643920898 secs
# Map data #155 saved! time = 1.8033373355865479 secs
# Map data #156 saved! time = 1.6600401401519775 secs
# Map data #157 saved! time = 1.9278411865234375 secs
# Map data #158 saved! time = 2.1427669525146484 secs
# Map data #159 saved! time = 3.049530029296875 secs
# Map data #160 saved! time = 3.3765952587127686 secs
# Map data #161 saved! time = 5.455862283706665 secs
# Map data #162 saved! time = 5.467914581298828 secs
# Map data #163 saved! time = 1.5591340065002441 secs
# Map data #164 saved! time = 1.7330007553100586 secs
# Map data #165 saved! time = 1.51712965965271 secs
# Map data #166 saved! time = 4.089587450027466 secs
# Map data #167 saved! time = 2.095837116241455 secs
# Map data #168 saved! time = 2.2989182472229004 secs
# Map data #169 saved! time = 2.0531671047210693 secs
# Map data #170 saved! time = 1.491150140762329 secs
# Map data #171 saved! time = 1.412191390991211 secs
# Map data #172 saved! time = 1.0384035110473633 secs
# Map data #173 saved! time = 2.67858624458313 secs
# Map data #174 saved! time = 1.4007949829101562 secs
# Map data #175 saved! time = 2.2378032207489014 secs
# Map data #176 saved! time = 2.066925048828125 secs
# Map data #177 saved! time = 1.2721381187438965 secs
# Map data #178 saved! time = 1.8339459896087646 secs
# Map data #179 saved! time = 1.4971377849578857 secs
# Map data #180 saved! time = 1.4601595401763916 secs
# Map data #181 saved! time = 1.637756586074829 secs
# Map data #182 saved! time = 1.5126392841339111 secs
# Map data #183 saved! time = 1.4031593799591064 secs
# Map data #184 saved! time = 1.225292682647705 secs
# Map data #185 saved! time = 1.158351182937622 secs
# Map data #186 saved! time = 5.309877872467041 secs
# Map data #187 saved! time = 5.298974514007568 secs

# %% [markdown]
# ## osumapper #2: rhythm model
#
# Train a rhythm model that decides where to place circles/sliders based on music.
#
# If you're using GPU and it reports a memory error, try setting batch_size parameter to a smaller value (that GPU can handle).

# %%
from act_train_rhythm import *;

train_params_p2 = {
    "divisor" : 4,
    "train_epochs" : 16,
    "train_batch_size" : None, # Default is 32 or based on machine specs
    "plot_history" : True,
    "too_many_maps_threshold" : 200,
    "train_epochs_many_maps" : 6,
    "data_split_count" : 80
};
model_p2 = step2_build_model()

# %% [markdown]
# Train the model and evaluate.<br>
# is_note_start accuracy should be about 0.8 to 0.9 based on my tests, others should be lower.
#
# **Note:** I changed the metrics from F1 to AUC in this version!! 0.5=guessing 1=perfect for AUC

# %%
model_p2 = step2_train_model(model_p2, train_params_p2)
step2_evaluate(model_p2)

# %% [markdown]
# Done! now save the model to the disk.

# %%
step2_save(model_p2)

# %% [markdown]
# ## osumapper #3: flow dataset construction
#
# Construct a dataset for the map flow generator.

# %%
from act_flow_ds import *;

flow_dataset_params = step3_set_params(note_group_size=10, step_size=5);
maps_flow = step3_read_maps_flow(flow_dataset_params);
step3_save_flow_dataset(maps_flow);

# hitsounds dataset, only for taiko maps
# maps_hs_af, maps_hs = step3_read_maps_hs(flow_dataset_params);
# step3_save_hs_dataset(maps_hs_af, maps_hs);

# pattern dataset, only for mania (remove the flow part for mania)
# data = step3_read_maps_pattern([]);
# step3_save_pattern_dataset(data);

# %% [markdown]
# That's it! The models are trained. Start making a new map with the other notebook.
