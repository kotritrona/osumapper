# %% [markdown]
# ### osu!nn #1: Map Dataset Reader
#
# This notebook reads a file "maplist.txt", then reads the .osu files and the relevant music files to convert into some data.
#
# Data that feeds the Deep Neural Network.
#
# Last edit: 2018/8/16

# %% [markdown]
# First of all, we need to install FFmpeg and specify its path here. It is needed to convert the .mp3 files to .wavs which Python can read.
#
# It's also fine to use any other converter, such as LAME: just edit the 24th line of osureader.py (starting with "subprocess.call") for the converter's parameters.
#
# **Then, fill maplist.txt  with the paths of .osu files you want to train with.** Otherwise it cannot find any of the maps because the maps are on my computer. The default model is trained with the Sota dataset including 44 maps of Sota Fujimori music.
#
# After that run the grid below to convert the maps.

# %%
import os, re, time
from osureader import * 

GLOBAL_VARS["ffmpeg_path"] = "D:\\StudyData\\Tensorflow\\ffmpeg\\bin\\ffmpeg.exe";
# or we can add ffmpeg path to PATH environment variable and,
# or in gcolab/linux,
# GLOBAL_VARS["ffmpeg_path"] = "ffmpeg";

mapdata_path = "mapdata/";

# the divisor parameter
divisor = 4;

# make sure the mapdata folder exists
if not os.path.isdir(mapdata_path):
    os.mkdir(mapdata_path);

with open("maplist.txt") as fp:
    fcont = fp.readlines();

# The following part is something I used to filter maps with difficulty names.
# Hmmmmm...
results = [];
# exclude_words = ["Easy", "Normal", "Hard", "Taiko", "Salad", "Platter", "Overdose", "Rain", "4K", "5K", "6K", "7K", "8K", "9K",
#                  "Kantan", "Futsuu", "Muzukashii", "Oni", "Field "];
for line in fcont:
#     if re.search("TV", line):
#         apd = True;
#         for kw in exclude_words:
#             if kw.lower() in line.strip().lower():
#                 apd = False;
#                 break;
#         if apd:
#             results.append(line.strip());
    results.append(line);

# Remove the originally existing npzs
for file in os.listdir(mapdata_path):
    if file.endswith(".npz"):
        os.remove(os.path.join(mapdata_path, file));

print("Number of filtered maps: {}".format(len(results)));

for k, mname in enumerate(results):
#     try:
    start = time.time()
    read_and_save_osu_file(mname.strip(), filename=os.path.join(mapdata_path, str(k)), divisor=divisor);
    end = time.time()
    print("Map data #" + str(k) + " saved! time = " + str(end - start) + " secs");
#     except:
#         print("Error occurred on map # " + str(k));

# If some map causes bug please tell me!! https://discord.gg/6t897aA
# Out:
# Number of filtered maps: 121
# Map data #0 saved! time = 3.169851779937744 secs
# Map data #1 saved! time = 3.0628390312194824 secs
# Map data #2 saved! time = 1.1850357055664062 secs
# Map data #3 saved! time = 1.5053191184997559 secs
# Map data #4 saved! time = 2.8996403217315674 secs
# Map data #5 saved! time = 1.4061455726623535 secs
# Map data #6 saved! time = 1.540687084197998 secs
# Map data #7 saved! time = 2.230724573135376 secs
# Map data #8 saved! time = 3.029146909713745 secs
# Map data #9 saved! time = 3.079921245574951 secs
# Map data #10 saved! time = 1.640228271484375 secs
# Map data #11 saved! time = 3.4734816551208496 secs
# Map data #12 saved! time = 2.0770018100738525 secs
# Map data #13 saved! time = 2.4733705520629883 secs
# Map data #14 saved! time = 2.30611515045166 secs
# Map data #15 saved! time = 2.9298298358917236 secs
# Map data #16 saved! time = 3.0640437602996826 secs
# Map data #17 saved! time = 2.849432945251465 secs
# Map data #18 saved! time = 2.4368059635162354 secs
# Map data #19 saved! time = 2.369797468185425 secs
# Map data #20 saved! time = 2.5901622772216797 secs
# Map data #21 saved! time = 2.973586320877075 secs
# Map data #22 saved! time = 2.7762362957000732 secs
# Map data #23 saved! time = 2.2999179363250732 secs
# Map data #24 saved! time = 2.4199812412261963 secs
# Map data #25 saved! time = 2.440227508544922 secs
# Map data #26 saved! time = 2.8901495933532715 secs
# Map data #27 saved! time = 1.562910556793213 secs
# Map data #28 saved! time = 3.3336262702941895 secs
# Map data #29 saved! time = 3.0471441745758057 secs
# Map data #30 saved! time = 2.8854713439941406 secs
# Map data #31 saved! time = 10.37423849105835 secs
# Map data #32 saved! time = 3.609133005142212 secs
# Map data #33 saved! time = 2.3435821533203125 secs
# Map data #34 saved! time = 2.0623347759246826 secs
# Map data #35 saved! time = 2.843546152114868 secs
# Map data #36 saved! time = 2.093616247177124 secs
# Map data #37 saved! time = 2.0311033725738525 secs
# Map data #38 saved! time = 2.1560771465301514 secs
# Map data #39 saved! time = 2.1560964584350586 secs
# Map data #40 saved! time = 1.4217731952667236 secs
# Map data #41 saved! time = 2.109274387359619 secs
# Map data #42 saved! time = 1.8279404640197754 secs
# Map data #43 saved! time = 4.437182188034058 secs
# Map data #44 saved! time = 3.952843427658081 secs
# Map data #45 saved! time = 2.812312126159668 secs
# Map data #46 saved! time = 1.96860933303833 secs
# Map data #47 saved! time = 1.7498562335968018 secs
# Map data #48 saved! time = 1.8748841285705566 secs
# Map data #49 saved! time = 4.030958890914917 secs
# Map data #50 saved! time = 2.531053066253662 secs
# Map data #51 saved! time = 2.765424966812134 secs
# Map data #52 saved! time = 2.6091866493225098 secs
# Map data #53 saved! time = 2.734178304672241 secs
# Map data #54 saved! time = 2.6248271465301514 secs
# Map data #55 saved! time = 3.8122105598449707 secs
# Map data #56 saved! time = 3.0310332775115967 secs
# Map data #57 saved! time = 1.5780494213104248 secs
# Map data #58 saved! time = 3.2809927463531494 secs
# Map data #59 saved! time = 1.5780017375946045 secs
# Map data #60 saved! time = 1.6873798370361328 secs
# Map data #61 saved! time = 2.374821186065674 secs
# Map data #62 saved! time = 2.3904552459716797 secs
# Map data #63 saved! time = 1.5624034404754639 secs
# Map data #64 saved! time = 2.9216482639312744 secs
# Map data #65 saved! time = 2.171717882156372 secs
# Map data #66 saved! time = 2.202970266342163 secs
# Map data #67 saved! time = 1.4061617851257324 secs
# Map data #68 saved! time = 1.1561493873596191 secs
# Map data #69 saved! time = 2.827922821044922 secs
# Map data #70 saved! time = 2.484196662902832 secs
# Map data #71 saved! time = 3.7184855937957764 secs
# Map data #72 saved! time = 2.234229564666748 secs
# Map data #73 saved! time = 2.2185733318328857 secs
# Map data #74 saved! time = 3.9997291564941406 secs
# Map data #75 saved! time = 3.7497143745422363 secs
# Map data #76 saved! time = 2.343597888946533 secs
# Map data #77 saved! time = 2.0623340606689453 secs
# Map data #78 saved! time = 12.545974254608154 secs
# Map data #79 saved! time = 1.5155165195465088 secs
# Map data #80 saved! time = 2.9372901916503906 secs
# Map data #81 saved! time = 1.3280272483825684 secs
# Map data #82 saved! time = 3.0622825622558594 secs
# Map data #83 saved! time = 1.468660593032837 secs
# Map data #84 saved! time = 2.0936007499694824 secs
# Map data #85 saved! time = 1.718606948852539 secs
# Map data #86 saved! time = 2.3592071533203125 secs
# Map data #87 saved! time = 1.6873960494995117 secs
# Map data #88 saved! time = 2.8122966289520264 secs
# Map data #89 saved! time = 2.281118154525757 secs
# Map data #90 saved! time = 4.405885219573975 secs
# Map data #91 saved! time = 3.9372329711914062 secs
# Map data #92 saved! time = 4.062192678451538 secs
# Map data #93 saved! time = 2.687314033508301 secs
# Map data #94 saved! time = 2.5154354572296143 secs
# Map data #95 saved! time = 1.9061312675476074 secs
# Map data #96 saved! time = 1.9685914516448975 secs
# Map data #97 saved! time = 2.593580484390259 secs
# Map data #98 saved! time = 2.57793927192688 secs
# Map data #99 saved! time = 1.7967283725738525 secs
# Map data #100 saved! time = 1.2186627388000488 secs
# Map data #101 saved! time = 1.4217729568481445 secs
# Map data #102 saved! time = 2.984178066253662 secs
# Map data #103 saved! time = 2.32795786857605 secs
# Map data #104 saved! time = 2.6091725826263428 secs
# Map data #105 saved! time = 3.109166383743286 secs
# Map data #106 saved! time = 2.624811887741089 secs
# Map data #107 saved! time = 1.0936648845672607 secs
# Map data #108 saved! time = 1.3905308246612549 secs
# Map data #109 saved! time = 2.312317371368408 secs
# Map data #110 saved! time = 2.1717376708984375 secs
# Map data #111 saved! time = 1.406146764755249 secs
# Map data #112 saved! time = 2.0310871601104736 secs
# Map data #113 saved! time = 2.2654621601104736 secs
# Map data #114 saved! time = 2.390453815460205 secs
# Map data #115 saved! time = 2.562314987182617 secs
# Map data #116 saved! time = 2.4060769081115723 secs
# Map data #117 saved! time = 2.6716835498809814 secs
# Map data #118 saved! time = 2.1404709815979004 secs
# Map data #119 saved! time = 2.312333583831787 secs
# Map data #120 saved! time = 1.9373791217803955 secs
